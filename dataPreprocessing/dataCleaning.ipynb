# %%
import pandas as pd
import numpy as np

# %%
filePath = '../thailand_foods.csv'

# %%
df = pd.read_csv(filePath)

# %%
df
# Out:
#                en_name            th_name  \
# 0                  Koi               ____
# 1            Kuai Chap            _______
# 2            Kuai Tiao         __________
# 3      Kuai Tiao Khaek      _____________
# 4    Kuai Tiao Kua Kai  _________________
# ..                 ...                ...
# 320              A Kao             ______
# 321              A Law           ________
# 322              A Law              _____
# 323              O Aew            _______
# 324      Ice Cream Pad           ________
#
#                                           ingredients     course  \
# 0              Beef+lime juice+fish sauce+chili+herbs  main dish
# 1            Pork belly+rice noodles+soy sauce+garlic  main dish
# 2    Rice noodles+pork+bean sprouts+garlic+fish sauce  main dish
# 3              Beef+noodles+curry powder+coconut milk  main dish
# 4                    Chicken+noodles+soy sauce+garlic  main dish
# ...

# %%
df.shape
# Out:
# (325, 6)

# %%
df.head(10)
# Out:
#                    en_name            th_name  \
# 0                      Koi               ____
# 1                Kuai Chap            _______
# 2                Kuai Tiao         __________
# 3          Kuai Tiao Khaek      _____________
# 4        Kuai Tiao Kua Kai  _________________
# 5         Kuai Tiao Pak Mo  _________________
# 6            Kuai Tiao Mon      _____________
# 7           Kuai Tiao Ruea     ______________
# 8        Kung Chae Nam Pla      _____________
# 9  Koey Yeung Kok Siang Bi  _________________
#
#                                         ingredients     course  \
# 0            Beef+lime juice+fish sauce+chili+herbs  main dish
# 1          Pork belly+rice noodles+soy sauce+garlic  main dish
# 2  Rice noodles+pork+bean sprouts+garlic+fish sauce  main dish
# 3            Beef+noodles+curry powder+coconut milk  main dish
# 4                  Chicken+noodles+soy sauce+garlic  main dish
# 5                      Pork+herbs+rice flour+garlic  main dish
# ...

# %%
df.tail(10)
# Out:
#             en_name        th_name                    ingredients   course  \
# 315        Luk Chup         ______  Mung beans+coconut milk+sugar  dessert
# 316        Som Chun         ______         Herbs+fruit+fish sauce    salad
# 317   Sankhaya Kuan   ______ (___)         Flour+coconut milk+egg  dessert
# 318  Sankhaya Nueng  ______ (____)         Flour+coconut milk+egg  dessert
# 319          Ang Ku         ______                        Unknown  dessert
# 320           A Kao         ______                        Unknown  dessert
# 321           A Law       ________                        Unknown  dessert
# 322           A Law          _____                        Unknown  dessert
# 323           O Aew        _______                        Unknown  dessert
# 324   Ice Cream Pad       ________                        Unknown  dessert
#
#     province   region
# 315  Various  Various
# 316  Various  Various
# 317  Various  Various
# 318  Various  Various
# 319  Unknown  Unknown
# ...
